# %%
import numpy as np
import pandas as pd
from confluent_kafka import Producer
from connect import get_connection
from random import randint
from simulation import transaktion_factory
from time import sleep
import socket


from confluent_kafka import Consumer

# %% [markdown]
# # Einlesen des Buchbestands

# %%
df_bestand = pd.read_csv('data/Bestand.csv', sep=';', encoding='unicode_escape')

# %%
bestand_cols=df_bestand.columns

# %%
for i in range(1):
    print(i)
# Out:
# 0

# %% [markdown]
# # Einlesen der Tabellen des Producers

# %%
c = Consumer({
    'bootstrap.servers': '0.0.0.0:9092',
    'group.id': socket.gethostname(),
    'auto.offset.reset': 'latest'
})

# %%
prod_Transaktion_cols={
    0:'Aktion',
    1:'Datum',
    2:'Fernleihe',
    3:'ID_Kunde',
    4:'ID_Exemplar',
    5:'Titel',
    6:'Autor',
    7:'Jahr',
    8:'Art',
    9:'Kennung',
   10:'Zugriffsort'
}

prod_Bewertung_cols={
    0:'Aktion',
    1:'ID_Kunde',
    2:'ID_Buch',
    3:'Wertung',
    4:'Rezension'
}

prod_Neukunden_cols={
    0:'Aktion',
    1:'ID_Kunde',
    #2:'c_count',
    3:'Kundennr',
    4:'Vorname_1',
    5:'Vorname_2',
    6:'Nachname',
    7:'Anrede',
    8:'PLZ',
    9:'Strasse',
   10:'Hausnr',
   11:'Mail',
   12:'Tel',
   13:'Geschlecht',
   14:'Geburtsdatum',
   15:'Beruf',
   16:'Titel',
   17:'PersoNr',
   18:'PersoValidTo' 
}

cols=[prod_Transaktion_cols,prod_Bewertung_cols,prod_Neukunden_cols]
topics=["Transaktion", "Bewertung", "Neukunden"]

dfd={}

# %%
for col, topic in zip(cols, topics):
    print(col, topic)

    dfd[topic] = pd.DataFrame(columns=list(col.values()))
    
    
    c.subscribe([topic])
    
    for i in range(10):
        msg = c.poll(10000)
        if msg is None:
            continue
    
        mrow = pd.DataFrame([msg.value().decode('utf-8').split(";")]).rename(columns=col)

        dfd[topic]=pd.concat([dfd[topic], mrow])

    dfd[topic] = dfd[topic].reset_index(drop=True)
    #c.close()
# Out:
# {0: 'Aktion', 1: 'Datum', 2: 'Fernleihe', 3: 'ID_Exemplar', 4: 'ID_Kunde', 5: 'Titel', 6: 'Autor', 7: 'Jahr', 8: 'Art', 9: 'Kennung', 10: 'Zugriffsort'} Transaktion
# {0: 'Aktion', 1: 'ID_Kunde', 2: 'ID_Buch', 3: 'Wertung', 4: 'Rezension'} Bewertung
# {0: 'Aktion', 1: 'ID_Kunde', 3: 'Kundennr', 4: 'Vorname_1', 5: 'Vorname_2', 6: 'Nachname', 7: 'Anrede', 8: 'PLZ', 9: 'Strasse', 10: 'Hausnr', 11: 'Mail', 12: 'Tel', 13: 'Geschlecht', 14: 'Geburtsdatum', 15: 'Beruf', 16: 'Titel', 17: 'PersoNr', 18: 'PersoValidTo'} Neukunden

# %%
dfd['Transaktion']
# Out:
#      Aktion                 Datum Fernleihe ID_Exemplar ID_Kunde  \
# 0  Rückgabe   2020-12-29 13:00:00      None         194     5512
# 1  Rückgabe   2020-12-29 18:00:00      None          23     4246
# 2     Leihe   2020-12-29 20:00:00     False         281     6391
# 3     Leihe   2020-12-29 23:00:00     False         118     2897
# 4     Leihe   2020-12-30 01:00:00     False         163     5716
#
#                        Titel                  Autor     Jahr        Art  \
# 0           Das siebte Kreuz           Anna Seghers   1942.0      Roman
# 1                     Carmen        Prosper Mérimée   1845.0    Novelle
# 2          Die Iden des März        Thornton Wilder   1949.0      Roman
# 3   Die Elixiere des Teufels        E.T.A. Hoffmann   1815.0      Roman
# 4   Wie ich Livingstone fand   Henry Morton Stanley   1872.0   Sachbuch
#
#      Kennung Zugriffsort
# 0   MUd29851    dmY93065
# 1   Xqy19630    AEL07341
# 2   Kxo56983    zCG32196
# 3   ShX80642    wOA38047
# 4   ecz15726    orE56291

# %%
dfd['Bewertung']
# Out:
#       Aktion ID_Kunde ID_Buch Wertung  \
# 0  Bewertung       78     718       7
# 1  Bewertung      131     312       7
# 2  Bewertung      164     435       7
# 3  Bewertung      243     486       6
# 4  Bewertung      164     435       7
#
#                                            Rezension
# 0   Gut geschrieben, mit einigen überraschenden W...
# 1                        Bietet solide Unterhaltung.
# 2   Ein gut strukturiertes Buch, das interessante...
# 3   Das Buch pendelte zwischen interessanten Ansä...
# 4   Ein gut strukturiertes Buch, das interessante...

# %%
dfd['Neukunden']
# Out:
#      Aktion ID_Kunde Kundennr    Vorname_1 Vorname_2   Nachname Anrede  \
# 0  Neukunde      669     5070      Sophie        nan     Köhler    Fr.
# 1  Neukunde      670     7045         Leon       nan   Herrmann   Herr
# 2  Neukunde      671     3514   Maximilian       nan     Schmid   Herr
# 3  Neukunde      672     8244         Luka       nan     Werner    Hr.
# 4  Neukunde      673     3631         Finn       nan   Hoffmann   Herr
#
#       PLZ               Strasse Hausnr                        Mail  \
# 0    3238            Kirchgasse    4.0       sophie.köhler@gmx.net
# 1    7778   Eichendorffstraße 9    nan   leon.herrmann@t-online.de
# 2   67822              Heideweg   10.0    maximilian.schmid@web.de
# 3    9477            Fasanenweg   10.0         luka.werner@gmx.net
# 4   18239           Neue Straße    2.0   finn.hoffmann@t-online.de
#
#               Tel Geschlecht Geburtsdatum                    Beruf  Titel  \
# 0   035325/828830   Weiblich   1970-10-03   Automobilkaufmann/frau   None
# 1   036427/213061          m   1991-04-16      Personalreferent/in   None
# 2    06362/565506          M   24.03.2005     Fluglotse/Fluglotsin   None
# 3   037343/280015          m   1962-08-20              Koch/Köchin   None
# 4   038207/827267          m   03.05.1931                Senior/in   None
#
#      PersoNr      PersoValidTo     2
# 0   FSR42958        06.04.2020   420
# 1   ATC19846        14/12/2020   421
# 2   RHM21370   Wed Jun 09 2021   422
# 3   DXT12036        2023-06-05   423
# 4   CVZ50846        2020-06-20   424

# %% [markdown]
# # Cleaning der Tabellen

# %% [markdown]
# ### Transaktion

# %%
# IDs zu int konvertieren
dfd['Transaktion']['ID_Exemplar'] = pd.to_numeric(dfd['Transaktion']['ID_Exemplar']).astype(int)
dfd['Transaktion']['ID_Kunde'] = pd.to_numeric(dfd['Transaktion']['ID_Kunde']).astype(int)
# Jahre zu int konvertieren
dfd['Transaktion']['Jahr'] = pd.to_numeric(dfd['Transaktion']['Jahr']).astype(int)

# Fernleihe zu true oder false konvertieren
dfd['Transaktion']['Fernleihe'] = np.where(dfd['Transaktion']['Fernleihe'].astype(str).str.contains("None"), False, dfd['Transaktion']['Fernleihe'] )
dfd['Transaktion']['Fernleihe'] = np.where(dfd['Transaktion']['Fernleihe'].astype(str).str.contains("False"), False, dfd['Transaktion']['Fernleihe'] )
dfd['Transaktion']['Fernleihe'] = np.where(dfd['Transaktion']['Fernleihe'].astype(str).str.contains("True"), True, dfd['Transaktion']['Fernleihe'] )

# %% [markdown]
# ### Bewertung

# %%
# IDs zu int konvertieren
dfd['Bewertung']['ID_Kunde'] = pd.to_numeric(dfd['Bewertung']['ID_Kunde']).astype(int)
dfd['Bewertung']['ID_Buch'] = pd.to_numeric(dfd['Bewertung']['ID_Buch']).astype(int)
dfd['Bewertung']['Wertung'] = pd.to_numeric(dfd['Bewertung']['Wertung']).astype(int)

# %% [markdown]
# ### Neukunden

# %%
# IDs zu int konvertieren
dfd['Neukunden']['ID_Kunde'] = pd.to_numeric(dfd['Neukunden']['ID_Kunde']).astype(int)
dfd['Neukunden']['Kundennr'] = pd.to_numeric(dfd['Neukunden']['Kundennr']).astype(int)

# Anreden konsistent machen 

dfd['Neukunden']['Anrede'] = dfd['Neukunden']['Anrede'].replace(['Fr\.'],'Frau', regex=True)
dfd['Neukunden']['Anrede'] = dfd['Neukunden']['Anrede'].replace(['Hr\.'],'Herr', regex=True)
# Titel: "None" to NaN
dfd['Neukunden']['Titel']  = np.where(dfd['Neukunden']['Titel'].str.contains("None"), np.nan, dfd['Neukunden']['Titel'] )
# Vorname_2: "nan" to NaN
dfd['Neukunden']['Vorname_2']  = np.where(dfd['Neukunden']['Vorname_2'].str.contains("nan"), np.nan, dfd['Neukunden']['Vorname_2'] )
# Hausnr: "nan" to NaN
dfd['Neukunden']['Hausnr'] = dfd['Neukunden']['Hausnr'].astype(str)
dfd['Neukunden']['Hausnr']  = np.where(dfd['Neukunden']['Hausnr'].str.contains("nan"), np.nan, dfd['Neukunden']['Hausnr'] )
# 4-stellige PLZ mit "0" präfixen 
dfd['Neukunden']['PLZ']    = dfd['Neukunden']['PLZ'].str.strip().str.rjust(5, '0')

# Hausnummern aus Strasse-Spalte extrahieren
def extract_hausnr(strasse):
  if pd.isna(strasse):
    return np.nan
  parts = strasse.split()
  if len(parts) > 1 and parts[-1].isdigit():
    return parts[-1]
  else:
    return np.nan
#Apply extract_hausnr, wenn 'Hausnr' NaN und entferne die Hausnummern aus der Strasse Spalte
dfd['Neukunden'].loc[dfd['Neukunden']['Hausnr'].isnull(), 'Hausnr'] = dfd['Neukunden'].loc[dfd['Neukunden']['Hausnr'].isnull(), 'Strasse'].apply(extract_hausnr)
dfd['Neukunden']['Strasse'] = dfd['Neukunden']['Strasse'].str.rsplit(expand=True)[0]
# Convert Hausnr to int
dfd['Neukunden']['Hausnr'] = pd.to_numeric(dfd['Neukunden']['Hausnr']).astype(int)

# Geschlecht konsistent machen 
dfd['Neukunden']['Geschlecht'] = dfd['Neukunden']['Geschlecht'].str.strip().replace(["^w$", "^W$"],'Weiblich', regex=True)
dfd['Neukunden']['Geschlecht'] = dfd['Neukunden']['Geschlecht'].str.strip().replace(["^m$", "^M$"],'Männlich', regex=True)

# Datumsspalten konsistent machen
dfd['Neukunden']['Geburtsdatum'] = pd.to_datetime(dfd['Neukunden']['Geburtsdatum'],format='mixed', dayfirst=True)
dfd['Neukunden']['PersoValidTo'] = pd.to_datetime(dfd['Neukunden']['PersoValidTo'],format='mixed', dayfirst=True)

# %% [markdown]
# ### Bestand

# %%
# Jahre zu int konvertieren
df_bestand['Jahr'] = pd.to_numeric(df_bestand['Jahr']).astype('Int64', errors='ignore')

# %% [markdown]
# ### Bestandskunden

# %%
df_bestandskunden = pd.read_csv('data/Kunde.csv', sep=',', encoding='unicode_escape')

df_bestandskunden['Aktion'] = pd.Series(['Bestandskunde' for x in range(len(df_bestandskunden.index))])


# IDs zu int konvertieren
df_bestandskunden['ID_Kunde'] = pd.to_numeric(df_bestandskunden['ID_Kunde']).astype(int)
df_bestandskunden['Kundennr'] = pd.to_numeric(df_bestandskunden['Kundennr']).astype(int)

# Anreden konsistent machen 

df_bestandskunden['Anrede'] = df_bestandskunden['Anrede'].replace(['Fr\.'],'Frau', regex=True)
df_bestandskunden['Anrede'] = df_bestandskunden['Anrede'].replace(['Hr\.'],'Herr', regex=True)

df_bestandskunden['Hausnr']  = np.where(df_bestandskunden['Hausnr'].astype(str).str.contains("NaN"), np.nan, df_bestandskunden['Hausnr'] )
# 4-stellige PLZ mit "0" präfixen 
df_bestandskunden['PLZ']    = df_bestandskunden['PLZ'].astype(str).str.strip().str.rjust(5, '0')

# Hausnummern aus Strasse-Spalte extrahieren
def extract_hausnr(strasse):
  if pd.isna(strasse):
    return np.nan
  parts = strasse.split()
  if len(parts) > 1 and parts[-1].isdigit():
    return parts[-1]
  else:
    return np.nan
#Apply extract_hausnr, wenn 'Hausnr' NaN und entferne die Hausnummern aus der Strasse Spalte
df_bestandskunden.loc[df_bestandskunden['Hausnr'].isnull(), 'Hausnr'] = df_bestandskunden.loc[df_bestandskunden['Hausnr'].isnull(), 'Strasse'].apply(extract_hausnr)
df_bestandskunden['Strasse'] = df_bestandskunden['Strasse'].str.rsplit(expand=True)[0]
# Convert Hausnr to int
df_bestandskunden['Hausnr'] = pd.to_numeric(df_bestandskunden['Hausnr']).astype('Int64')

# Geschlecht konsistent machen 
df_bestandskunden['Geschlecht'] = df_bestandskunden['Geschlecht'].str.strip().replace(["^w$", "^W$"],'Weiblich', regex=True)
df_bestandskunden['Geschlecht'] = df_bestandskunden['Geschlecht'].str.strip().replace(["^m$", "^M$"],'Männlich', regex=True)

# Datumsspalten konsistent machen
df_bestandskunden['Geburtsdatum'] = pd.to_datetime(df_bestandskunden['Geburtsdatum'],format='mixed', dayfirst=True)
df_bestandskunden['PersoValidTo'] = pd.to_datetime(df_bestandskunden['PersoValidTo'],format='mixed', dayfirst=True)
# Out:
# /tmp/ipykernel_1109/4017946161.py:29: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '['8' '6' '4' '8' '3' '7' '6' '4' '3' '8' '3' '6' '8' '3' '8' '7' '3' '8'
#  '2' '8' '1' '5' '4' '3' '3' '5' '2' '8' '5' '7' '7' '3' '7' '7' '9' '1'
#  '5' '10' '4' '5' '4' '1' '9' '10' '10' '7' '8' '2' '10' '5' '8' '6' '8'
#  '4' '3' '4' '9' '9' '10' '5' '4' '2' '7' '7' '3' '7' '5' '2' '2' '8' '9'
#  '8' '3' '4' '3' '10' '10' '3' '10' '5' '9' '5' '7' '10']' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_bestandskunden.loc[df_bestandskunden['Hausnr'].isnull(), 'Hausnr'] = df_bestandskunden.loc[df_bestandskunden['Hausnr'].isnull(), 'Strasse'].apply(extract_hausnr)

# %%
df_bestandskunden
# Out:
#      ID_Kunde  Kundennr Vorname_1  Vorname_2   Nachname Anrede    PLZ  \
# 0           1      8366    Elias         NaN    Kaiser    Herr  24619
# 1           2      9208     Elias        NaN     KÃ¶nig   Herr  54574
# 2           3      3837    Moritz        NaN   MÃ¼ller    Herr  01097
# 3           4      7306    Leonie        NaN   Herrmann   Frau  23923
# 4           5      4589    Elias         NaN    KrÃ¼ger   Herr  55469
# ..        ...       ...       ...        ...        ...    ...    ...
# 495       496      5019     Louis        NaN    Schulze   Herr  25712
# 496       497      6603    Sophie        NaN      Braun   Frau  16259
# 497       498      4465   Philipp        NaN     Kaiser   Herr  08606
# 498       499      6695    Elias         NaN   Hoffmann   Herr  19230
# 499       500      8719       Mia        NaN     Kaiser   Frau  96196
#
#                 Strasse  Hausnr                        Mail            Tel  \
# 0         MozartstraÃe       8         elias.kaiser@web.de   04323/829874
# 1        MÃ¼hlenstraÃe       1      elias.kÃ¶nig@gmail.com   06594/313132
# 2    EichendorffstraÃe       8    moritz.mÃ¼ller@gmail.com    0351/156882
# 3            Marktplatz       1      leonie.herrmann@web.de   038821/70723
# 4              Kirchweg       4     elias.krÃ¼ger@gmail.com   06766/872686
# ..                  ...     ...                         ...            ...
# 495       RÃ¶merstraÃe       7     louis.schulze@gmail.com   04825/579613
# 496                Neue      10    sophie.braun@t-online.de  033451/330710
# 497           Breslauer       9  philipp.kaiser@t-online.de  037463/768172
# 498               Lange      10      elias.hoffmann@gmx.net  038856/699772
# 499                  Im       6           mia.kaiser@web.de   09504/206577
#
#     Geschlecht Geburtsdatum                                    Beruf  Titel  \
# 0     Männlich   1988-02-22                            Product Owner    Dr.
# 1     Männlich   1997-07-28  Sektions- und PrÃ¤parationsassistent/in    NaN
# 2     Männlich   1963-08-20                             Data Analyst    NaN
# 3     Weiblich   1952-07-07                               Senior/in     NaN
# 4     Männlich   1995-07-13                              Landwirt/in    NaN
# ..         ...          ...                                      ...    ...
# 495   Männlich   2006-01-27                           Bauzeichner/in    NaN
# 496   Weiblich   1967-04-02                            Finanzwirt/in    NaN
# 497  MÃ¤nnlich   1940-02-16                                Senior/in    NaN
# 498   Männlich   1950-01-15                               Senior/in   Prof.
# 499   Weiblich   2005-09-28                 Immobilienkaufmann/frau     NaN
#
#       PersoNr PersoValidTo         Aktion
# 0    NPE20376   2021-05-27  Bestandskunde
# 1    GMN18965   2024-01-26  Bestandskunde
# 2    DNS52984   2022-11-05  Bestandskunde
# 3    IXU64239   2025-03-27  Bestandskunde
# 4    MJB45392   2025-01-15  Bestandskunde
# ..        ...          ...            ...
# 495  XGP73984   2025-03-31  Bestandskunde
# 496  MVR46513   2023-10-21  Bestandskunde
# 497  FIQ27658   2020-08-02  Bestandskunde
# 498  CNG07613   2020-05-22  Bestandskunde
# 499  STX90835   2020-06-24  Bestandskunde
#
# [500 rows x 18 columns]

# %%
dfd['Neukunden']
# Out:
#      Aktion  ID_Kunde  Kundennr Vorname_1 Vorname_2    Nachname Anrede    PLZ  \
# 0  Neukunde        62      6678      Noah       NaN     Kaiser    Herr  37620
# 1  Neukunde        63      5996    Julian       NaN   Schröder    Herr  15377
# 2  Neukunde        64      7378     Sofia       NaN    Hoffmann   Frau  99628
# 3  Neukunde        65      8073       Mia       NaN       Wolf    Frau  88524
# 4  Neukunde        66      9105     Jonas       NaN    Herrmann   Herr  99869
# 5  Neukunde        67      5865      Lara       NaN       Wolf    Frau  83565
# 6  Neukunde        68      8074     Emily       NaN     Schulze   Frau  16259
# 7  Neukunde        69      3872    Leonie       NaN      Mayer    Frau  25712
# 8  Neukunde        70      5321       Ben       NaN     Köhler    Herr  67586
# 9  Neukunde        71      2529     Lena        NaN      Krause   Frau  86747
#
#          Strasse  Hausnr                         Mail             Tel  \
# 0             Im       2           noah.kaiser@web.de    05533/409541
# 1           Neue       9    julian.schröder@gmail.com   033437/244553
# 2     Fliederweg       8   sofia.hoffmann@t-online.de   036373/802292
# 3    Rosenstraße       6         mia.wolf@t-online.de    07374/395656
# 4     Kirchplatz       8     jonas.herrmann@gmail.com    03621/202533
# 5   Königsberger       4             lara.wolf@web.de    08092/439859
# 6      Buchenweg       8         emily.schulze@web.de   033451/320243
# 7    Hauptstraße       6       leonie.mayer@gmail.com    04825/570120
# 8     Kirchgasse       7           ben.köhler@gmx.net    06733/682676
# 9  Wilhelmstraße       5      lena.krause@t-online.de    09087/143513
#
#   Geschlecht Geburtsdatum                                      Beruf Titel  \
# 0   Männlich   1944-02-28                                  Senior/in   NaN
# 1   Männlich   1939-08-05                                  Senior/in   NaN
# 2   Weiblich   1978-07-24     Sektions- und Präparationsassistent/in   NaN
# 3   Weiblich   1986-03-04                            Immobilienwirt    NaN
# 4   Männlich   1976-05-29                              Controller/in   Dr.
# 5   Weiblich   1957-10-17                       Rettungssanitäter/in   NaN
# 6   Weiblich   1942-09-08                                  Senior/in   NaN
# 7   Weiblich   1987-07-08                            Bauzeichner/in    NaN
# 8   Männlich   1965-11-03                  Maler/in und Lackierer/in   NaN
# 9   Weiblich   1980-05-11    Sektions- und Präparationsassistent/in    NaN
#
#      PersoNr PersoValidTo     2
# 0   XVP47503   2025-06-05   314
# 1   RKJ42136   2022-01-03   315
# 2   QAN35490   2025-08-16   316
# 3   KRQ91853   2025-06-06   317
# 4   TAR62891   2023-03-23   318
# 5   ZPW90287   2021-05-28   319
# 6   SPX95312   2021-08-13   320
# 7   AMH06412   2022-05-18   321
# 8   XEV31827   2024-02-07   322
# 9   FEB46382   2022-10-17   323

# %%
dfd['Transaktion']
# Out:
#       Aktion                 Datum Fernleihe  ID_Exemplar  ID_Kunde  \
# 0      Leihe   2025-01-14 19:00:00     False          295      5508
# 1      Leihe   2025-01-14 19:00:00     False          179      2908
# 2   Rückgabe   2025-01-15 00:00:00     False            7      4187
# 3      Leihe   2025-01-15 02:00:00     False          282      4946
# 4      Leihe   2025-01-15 05:00:00     False          168      2712
# 5      Leihe   2025-01-15 07:00:00     False           36      3314
# 6   Rückgabe   2025-01-15 12:00:00     False           37      1918
# 7      Leihe   2025-01-15 12:00:00     False          198      2899
# 8      Leihe   2025-01-15 12:00:00     False          120      2445
# 9      Leihe   2025-01-15 15:00:00     False          168      6562
# 10     Leihe   2025-01-15 16:00:00     False           51      2754
# 11     Leihe   2025-01-15 17:00:00     False          222       927
# 12  Rückgabe   2025-01-15 22:00:00     False          129        40
# 13  Rückgabe   2025-01-16 03:00:00     False          229      5652
# 14     Leihe   2025-01-16 03:00:00     False          220      6467
# 15  Rückgabe   2025-01-16 08:00:00     False          289       673
# 16     Leihe   2025-01-16 09:00:00     False           51      2521
# 17     Leihe   2025-01-16 12:00:00     False          244      6279
# 18     Leihe   2025-01-16 15:00:00     False          292      4393
# 19     Leihe   2025-01-16 16:00:00     False          173      5255
# 20  Rückgabe   2025-01-16 20:00:00     False          177      4854
# 21  Rückgabe   2025-01-17 00:00:00     False          109      2506
# 22     Leihe   2025-01-17 00:00:00     False          235      4937
#
#                                                 Titel  \
# 0                                          Love Story
# 1    Gödel, Escher, Bach – ein Endloses Geflochten...
# 2                             Die Asche meiner Mutter
# 3                                            Der Pate
# 4                      Deutschland. Ein Wintermärchen
# 5                                    Schindlers Liste
# 6                             Kleiner Mann – was nun?
# 7                                       Struwwelpeter
# 8                                  Der arme Spielmann
# 9                                         Eifel-Liebe
# 10                                    Die Vollidioten
# 11                     Die Physiologie des Geschmacks
# 12                                Gestern, vorgestern
# 13                           Der moderne Kapitalismus
# 14                        Die Caine war ihr Schicksal
# 15                                         Das Lachen
# 16                                     Die Welträtsel
# 17                                   Tod in Hollywood
# 18                                          La Storia
# 19                       Die Geschichte meines Lebens
# 20                                         Stalingrad
# 21                        Schnee der auf Zedern fällt
# 22                                       Eugen Onegin
#
#                              Autor  Jahr           Art    Kennung Zugriffsort
# 0                      Erich Segal  1970         Roman   bwc42965    wVE86507
# 1            Douglas R. Hofstadter  1979      Sachbuch   rKS31970    rWu13725
# 2                    Frank McCourt  1996         Roman   CwE93710    plV36087
# 3                       Mario Puzo  1969         Roman   CdH54832    yFl09845
# 4                   Heinrich Heine  1844          Epos   lkS13928    MOr03729
# 5                  Thomas Keneally  1982         Roman   BdD79820    Sbn62495
# 6                     Hans Fallada  1932         Roman   Osy15037    lkW13504
# 7                Heinrich Hoffmann  1845    Kinderbuch   nRG51072    Dux16349
# 8                Franz Grillparzer  1847       Novelle   uyI14523    HTR95106
# 9                 Jacques Berndorf  2002         Roman   qBZ67804    CFU80741
# 10               Eckhard Henscheid  1973         Roman   Pbc96502    nof78913
# 11   Jean Anthelme Brillat-Savarin  1826      Sachbuch   DhC23850    bsa94127
# 12                    Samuel Agnon  1945         Roman   utm96357    Mrd13620
# 13                  Werner Sombart  1902      Sachbuch   STf31528    hmi27840
# 14                     Herman Wouk  1951         Roman   NcB38246    GzL41308
# 15                   Henri Bergson  1900   Philosophie   mQI30964    knd90862
# 16                   Ernst Haeckel  1899      Sachbuch   Jys60421    iFP02975
# 17                    Evelyn Waugh  1948         Roman   ZFg79136    Mif18239
# 18                    Elsa Morante  1974         Roman   PfQ05619    aHA30421
# 19                     George Sand  1854         Roman   VtF96810    RBG59416
# 20                Theodor Plievier  1945         Roman   twF26749    xHr92703
# 21                  David Guterson  1994         Roman   SyC36781    cIr61952
# 22              Alexander Puschkin  1833         Roman   juT78902    PmU23805

# %% [markdown]
# # Aufbau der Tabellen für das Core DWH

# %%
dfs={}

# %%
Kunde_cols={
    0:'ID_Kunde',
    1:'ID_Mitgliedsstatus',
    2:'Kundennr',
    3:'Vorname_1',
    4:'Vorname_2',
    5:'Nachname',
    6:'Anrede',
    7:'Titel',
    8:'PLZ',
    9:'Strasse',
   10:'Hausnr',
   11:'Mail',
   12:'Tel',
   13:'Geschlecht',
   14:'Geburtsdatum',
   15:'Beruf',
   16:'PersoNr',
   17:'PersoValidTo', 
   18:'Mitglied seit',
   19:'Mitglied bis' 
}

Bewertung_cols={
    1:'ID_Kunde',
    2:'ID_Buch',
    3:'Wertung',
    4:'Rezension'
}

Buch_cols={
    1:'ID_Kunde',
    2:'ID_Buch',
    3:'Wertung',
    4:'Rezension'
}

Exemplare_cols={
    1:'ID_Bestand',
    2:'Nr',
    3:'Kennung',
    4:'Zugriffsort',
    5:'Zustand'
}

Buch_cols={
    1:'ID_Autor',
    2:'Nr',
    3:'Titel',
    4:'Jahr',
    5:'Art',
}

Leihe_cols={
    0:'ID_Kunde',
    1:'ID_Exemplar',
    2:'Ausleihdatum',
    3:'Rueckgabedatum',
    4:'Verlaengerungsstatus',
    5:'Mahnstatus',
    6:'Fernleihe'
}

Mitgliedsstatus_cols={
    0:'ID_Mitgliedsstatus',
    2:'Bezeichnung',
    3:'Jahresbeitrag',
    4:'Mahnbetrag'
}

Beitragszahlung_cols={
    0:'ID_Zahlung',
    2:'ID_Kunde',
    3:'Datum',
    4:'Betrag',
}

# %%
dfs['Kunde']     = dfd['Neukunden'].reindex(columns=list(Kunde_cols.values()))
dfs['Bewertung'] = dfd['Bewertung'].reindex(columns=list(Bewertung_cols.values()))
dfs['Exemplare'] = df_bestand.reindex(columns=list(Exemplare_cols.values())).rename(columns={
                                                                        'ID_Bestand':'ID_Exemplar',
                                                                        'Nr':'ID_Buch'    
                                                                        })

dfs['Autor']   = df_bestand[['Autor', 'Herkunft']].drop_duplicates().reset_index(drop=True).reset_index().rename(columns={'index':'ID_Autor'})

dfs['Buch']    = pd.merge(df_bestand, 
                          dfs['Autor'], 
                          on=['Autor']
                         )[list(Buch_cols.values())]                                  \
                                                    .drop_duplicates()                \
                                                    .reset_index(drop=True)           \
                                                    .rename(columns={'Nr':'ID_Buch'})

dfs['Leihe'] = dfd['Transaktion'].reindex(columns=list(Leihe_cols.values())).reset_index().rename(columns={'index':'ID_Leihe'})


### more ###
dfs['Mitgliedsstatus'] = pd.DataFrame(columns=list(Mitgliedsstatus_cols.values()))
dfs['Beitragszahlung'] = dfd['Neukunden'].reindex(columns=list(Beitragszahlung_cols.values()))

# %%
dfs['Leihe'][['Ausleihdatum']]

dfd['Transaktion']

df = dfs['Leihe'].copy()
#df.loc[df["Aktion"] == "Leihe", "gender"] = 1

# %%
dfs['Leihe']['Ausleihdatum']=pd.to_datetime(dfs['Leihe']['Ausleihdatum'])
dfs['Leihe'].loc[dfd['Transaktion']['Aktion'] == "Leihe", "Ausleihdatum"] = dfd['Transaktion']['Datum']

dfs['Leihe']['Rueckgabedatum']=pd.to_datetime(dfs['Leihe']['Rueckgabedatum'])
dfs['Leihe'].loc[dfd['Transaktion']['Aktion'] == "Rückgabe", "Rueckgabedatum"] = dfd['Transaktion']['Datum']

# %%
dfs['Leihe']
# Out:
#     ID_Leihe  ID_Kunde  ID_Exemplar        Ausleihdatum      Rueckgabedatum  \
# 0          0      5508          295 2025-01-14 19:00:00                 NaT
# 1          1      2908          179 2025-01-14 19:00:00                 NaT
# 2          2      4187            7                 NaT 2025-01-15 00:00:00
# 3          3      4946          282 2025-01-15 02:00:00                 NaT
# 4          4      2712          168 2025-01-15 05:00:00                 NaT
# 5          5      3314           36 2025-01-15 07:00:00                 NaT
# 6          6      1918           37                 NaT 2025-01-15 12:00:00
# 7          7      2899          198 2025-01-15 12:00:00                 NaT
# 8          8      2445          120 2025-01-15 12:00:00                 NaT
# 9          9      6562          168 2025-01-15 15:00:00                 NaT
# 10        10      2754           51 2025-01-15 16:00:00                 NaT
# 11        11       927          222 2025-01-15 17:00:00                 NaT
# 12        12        40          129                 NaT 2025-01-15 22:00:00
# 13        13      5652          229                 NaT 2025-01-16 03:00:00
# 14        14      6467          220 2025-01-16 03:00:00                 NaT
# 15        15       673          289                 NaT 2025-01-16 08:00:00
# 16        16      2521           51 2025-01-16 09:00:00                 NaT
# 17        17      6279          244 2025-01-16 12:00:00                 NaT
# 18        18      4393          292 2025-01-16 15:00:00                 NaT
# 19        19      5255          173 2025-01-16 16:00:00                 NaT
# 20        20      4854          177                 NaT 2025-01-16 20:00:00
# 21        21      2506          109                 NaT 2025-01-17 00:00:00
# 22        22      4937          235 2025-01-17 00:00:00                 NaT
#
#     Verlaengerungsstatus  Mahnstatus Fernleihe
# 0                    NaN         NaN     False
# 1                    NaN         NaN     False
# 2                    NaN         NaN     False
# 3                    NaN         NaN     False
# 4                    NaN         NaN     False
# 5                    NaN         NaN     False
# 6                    NaN         NaN     False
# 7                    NaN         NaN     False
# 8                    NaN         NaN     False
# 9                    NaN         NaN     False
# 10                   NaN         NaN     False
# 11                   NaN         NaN     False
# 12                   NaN         NaN     False
# 13                   NaN         NaN     False
# 14                   NaN         NaN     False
# 15                   NaN         NaN     False
# 16                   NaN         NaN     False
# 17                   NaN         NaN     False
# 18                   NaN         NaN     False
# 19                   NaN         NaN     False
# 20                   NaN         NaN     False
# 21                   NaN         NaN     False
# 22                   NaN         NaN     False

# %%
# Out:
# %6|1727373654.407|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Disconnected (after 175203ms in state UP, 1 identical error(s) suppressed)
# %6|1727373654.408|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727373654.635|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727373654.652|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY, 1 identical error(s) suppressed)
# %6|1727373654.880|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY, 1 identical error(s) suppressed)
# %3|1727373658.250|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1727373658.284|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1727373658.806|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1727373685.023|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1727373686.023|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1727373687.995|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 3 identical error(s) suppressed)

# %%
df.columns

# %%
# Out:
# %6|1727427857.981|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727427857.981|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727427858.255|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY, 1 identical error(s) suppressed)
# %6|1727427858.276|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY, 1 identical error(s) suppressed)
# %3|1727427861.984|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1727427862.191|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1727427863.247|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %6|1727427872.351|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Disconnected (after 0ms in state APIVERSION_QUERY)
# %6|1727427872.352|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %5|1727427877.413|PARTCNT|rdkafka#consumer-1| [thrd:main]: Topic Transaktion partition count changed from 1 to 0
# %5|1727427877.413|PARTCNT|rdkafka#consumer-1| [thrd:main]: Topic Bewertung partition count changed from 1 to 0
# %5|1727427877.413|PARTCNT|rdkafka#consumer-1| [thrd:main]: Topic Neukunden partition count changed from 1 to 0
# %4|1727427877.413|CLUSTERID|rdkafka#consumer-1| [thrd:main]: Broker 0.0.0.0:9092/bootstrap reports different ClusterId "46LAqw0-QiS1vDDzr9Y0zQ" than previously known "bSIPLCEXR-Ky5noOiLJfXg": a client must not be simultaneously connected to multiple clusters
# %6|1727432875.687|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected (after 4995827ms in state UP)
# %6|1727432875.690|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Disconnected (after 196028ms in state UP, 1 identical error(s) suppressed)
# %6|1727432875.691|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 1ms in state APIVERSION_QUERY)
# %6|1727432875.884|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY, 1 identical error(s) suppressed)
# %6|1727432875.885|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727432876.055|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY, 1 identical error(s) suppressed)
# %3|1727432879.216|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1727432879.377|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1727432881.114|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1727432906.498|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 24 identical error(s) suppressed)
# %3|1727432908.332|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1727432908.332|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 13 identical error(s) suppressed)
# %3|1727432938.440|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 18 identical error(s) suppressed)
# %3|1727432939.499|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 24 identical error(s) suppressed)
# %3|1727432946.322|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727432968.440|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1727432972.499|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1727432984.134|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727432999.500|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1727433002.500|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1727433014.185|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1727433032.501|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 20 identical error(s) suppressed)
# %3|1727433033.440|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 21 identical error(s) suppressed)
# %6|1727433041.501|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727433041.659|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727433044.185|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Disconnected (after 1ms in state APIVERSION_QUERY)
# %4|1727433054.203|CLUSTERID|rdkafka#consumer-1| [thrd:main]: Broker GroupCoordinator/1 reports different ClusterId "HNH5s6KrQBGRE2mf14Oz-w" than previously known "46LAqw0-QiS1vDDzr9Y0zQ": a client must not be simultaneously connected to multiple clusters
# %6|1727439639.861|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727439640.071|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727439640.079|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY, 1 identical error(s) suppressed)
# %6|1727439640.237|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY, 1 identical error(s) suppressed)
# %3|1727439644.041|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1727439644.285|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1727439644.354|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %6|1727439661.639|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727439661.777|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Disconnected (after 0ms in state APIVERSION_QUERY)
# %6|1727439661.778|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %4|1727439748.384|CLUSTERID|rdkafka#consumer-1| [thrd:main]: Broker 127.0.0.1:9092/1 reports different ClusterId "Akq9T7NaRMG23O5c14Jovg" than previously known "HNH5s6KrQBGRE2mf14Oz-w": a client must not be simultaneously connected to multiple clusters

# %% [markdown]
# # Schicke die Tabellen an den SQL Server

# %%
from sqlalchemy import create_engine, inspect, text

USER = 'root'
PASSWORD = 'root'
HOST = 'localhost'          # see yml file
PORT = 3307
DATABASE = 'test_db_1'
 

def get_connection(database=DATABASE):
    return create_engine(
        url="mysql+pymysql://{0}:{1}@{2}:{3}/{4}"\
            .format(USER, PASSWORD, HOST, PORT, database)
    )

engine = get_connection('mysql')
with engine.connect() as connection:
    insp = inspect(engine)
    db_list = insp.get_schema_names()
    print(f"Connection to the {HOST} for user {USER} created successfully.")
    if DATABASE not in db_list:
        sql = text(f"CREATE DATABASE {DATABASE} CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;")
        result = connection.execute(sql)
        if result:
            print(f"Database {DATABASE} created!")
# Out:
# Connection to the localhost for user root created successfully.

# %%
for Tabelle in dfs.keys():
    dfs[Tabelle].to_sql(Tabelle, con=engine,schema=DATABASE, index=False, if_exists='append')

# %%
CDW_Tabellen_Liste = insp.get_table_names()

Statische_Tabellen = ['Exemplare', 'Autor', 'Buch']

for Tabelle in Statische_Tabellen:
    if Tabelle not in CDW_Tabellen_Liste:
        dfs[Tabelle].to_sql(Tabelle, con=engine,schema=DATABASE, index=False, if_exists='replace') 

for Tabelle in dfs.keys():
    if Tabelle not in Statische_Tabellen:
        dfs[Tabelle].to_sql(Tabelle, con=engine,schema=DATABASE, index=False, if_exists='append')
# Out:
# Kunde
# Bewertung
# Leihe
# Mitgliedsstatus
# Beitragszahlung
# %3|1727373845.031|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1727373868.033|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1727373871.073|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1727373875.033|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1727373903.034|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1727373905.034|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1727373909.059|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727373934.035|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 22 identical error(s) suppressed)
# %3|1727373937.034|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1727373948.267|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727373965.036|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1727373968.021|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 24 identical error(s) suppressed)
# %3|1727373988.020|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727373996.037|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 15 identical error(s) suppressed)
# %3|1727373998.021|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 22 identical error(s) suppressed)
# %3|1727374018.021|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1727374026.038|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1727374028.611|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 20 identical error(s) suppressed)
# %3|1727374056.157|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727374058.041|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1727374058.613|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 25 identical error(s) suppressed)
# %3|1727374088.042|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 18 identical error(s) suppressed)
# %3|1727374088.614|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1727374095.045|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727374118.043|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1727374119.043|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1727374131.737|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727374148.044|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1727374149.044|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 23 identical error(s) suppressed)
# %3|1727374168.639|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727374178.045|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 18 identical error(s) suppressed)
# %3|1727374179.046|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1727374206.805|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727374208.619|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 14 identical error(s) suppressed)
# %3|1727374209.047|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 24 identical error(s) suppressed)
# %3|1727374236.805|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 3 identical error(s) suppressed)
# %3|1727374239.048|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 16 identical error(s) suppressed)
# %3|1727374240.048|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 24 identical error(s) suppressed)
# %3|1727374269.050|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 20 identical error(s) suppressed)
# %3|1727374272.050|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1727374276.118|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727374299.052|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 21 identical error(s) suppressed)
# %3|1727374303.621|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 19 identical error(s) suppressed)
# %3|1727374313.608|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1727374329.053|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Connect to ipv4#0.0.0.0:9092 failed: Connection refused (after 0ms in state CONNECT, 20 identical error(s) suppressed)
# %6|1727374336.053|FAIL|rdkafka#consumer-1| [thrd:0.0.0.0:9092/bootstrap]: 0.0.0.0:9092/bootstrap: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727374336.325|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY)
# %6|1727374336.605|FAIL|rdkafka#consumer-1| [thrd:127.0.0.1:9092/1]: 127.0.0.1:9092/1: Disconnected while requesting ApiVersion: might be caused by incorrect security.protocol configuration (connecting to a SSL listener?) or broker version is < 0.10 (see api.version.request) (after 0ms in state APIVERSION_QUERY, 1 identical error(s) suppressed)
# %6|1727374341.929|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: 127.0.0.1:9092: Disconnected (after 1ms in state APIVERSION_QUERY)
# %5|1727374351.965|PARTCNT|rdkafka#consumer-1| [thrd:main]: Topic Bewertung partition count changed from 1 to 0
# %5|1727374351.966|PARTCNT|rdkafka#consumer-1| [thrd:main]: Topic Neukunden partition count changed from 1 to 0
# %4|1727374351.966|CLUSTERID|rdkafka#consumer-1| [thrd:main]: Broker GroupCoordinator/1 reports different ClusterId "hiejHQUyRHedEDoUOSGqbA" than previously known "Huawp7d3QN-2fETxNr0jmA": a client must not be simultaneously connected to multiple clusters

# %%
df_bestandskunden = pd.read_csv('data/Kunde.csv', sep=',', encoding='unicode_escape')

df_bestandskunden['Aktion'] = pd.Series(['Bestandskunde' for x in range(len(df_bestandskunden.index))])


# IDs zu int konvertieren
df_bestandskunden['ID_Kunde'] = pd.to_numeric(df_bestandskunden['ID_Kunde']).astype(int)
df_bestandskunden['Kundennr'] = pd.to_numeric(df_bestandskunden['Kundennr']).astype(int)

# Anreden konsistent machen 

df_bestandskunden['Anrede'] = df_bestandskunden['Anrede'].replace(['Fr\.'],'Frau', regex=True)
df_bestandskunden['Anrede'] = df_bestandskunden['Anrede'].replace(['Hr\.'],'Herr', regex=True)

df_bestandskunden['Hausnr']  = np.where(df_bestandskunden['Hausnr'].astype(str).str.contains("NaN"), np.nan, df_bestandskunden['Hausnr'] )
# 4-stellige PLZ mit "0" präfixen 
df_bestandskunden['PLZ']    = df_bestandskunden['PLZ'].astype(str).str.strip().str.rjust(5, '0')

# Hausnummern aus Strasse-Spalte extrahieren
def extract_hausnr(strasse):
  if pd.isna(strasse):
    return np.nan
  parts = strasse.split()
  if len(parts) > 1 and parts[-1].isdigit():
    return parts[-1]
  else:
    return np.nan
#Apply extract_hausnr, wenn 'Hausnr' NaN und entferne die Hausnummern aus der Strasse Spalte
df_bestandskunden.loc[df_bestandskunden['Hausnr'].isnull(), 'Hausnr'] = df_bestandskunden.loc[df_bestandskunden['Hausnr'].isnull(), 'Strasse'].apply(extract_hausnr)
df_bestandskunden['Strasse'] = df_bestandskunden['Strasse'].str.rsplit(expand=True)[0]
# Convert Hausnr to int
df_bestandskunden['Hausnr'] = pd.to_numeric(df_bestandskunden['Hausnr']).astype('Int64')

# Geschlecht konsistent machen 
df_bestandskunden['Geschlecht'] = df_bestandskunden['Geschlecht'].str.strip().replace(["^w$", "^W$"],'Weiblich', regex=True)
df_bestandskunden['Geschlecht'] = df_bestandskunden['Geschlecht'].str.strip().replace(["^m$", "^M$"],'Männlich', regex=True)

# Datumsspalten konsistent machen
df_bestandskunden['Geburtsdatum'] = pd.to_datetime(df_bestandskunden['Geburtsdatum'],format='mixed', dayfirst=True)
df_bestandskunden['PersoValidTo'] = pd.to_datetime(df_bestandskunden['PersoValidTo'],format='mixed', dayfirst=True)


df_bestandskunden = df_bestandskunden.reindex(columns=list(Kunde_cols.values()))
