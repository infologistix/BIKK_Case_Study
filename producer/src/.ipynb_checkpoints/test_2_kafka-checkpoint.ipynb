# %%
import numpy as np
import pandas as pd
from confluent_kafka import Producer
from connect import get_connection
from random import randint
from simulation import transaktion_factory
from time import sleep
import socket


from confluent_kafka import Consumer

# %% [markdown]
# # Einlesen des Buchbestands

# %%
df_bestand = pd.read_csv('data/Bestand.csv', sep=';', encoding='unicode_escape')

# %%
bestand_cols=df_bestand.columns

# %% [markdown]
# # Einlesen der Tabellen des Producers

# %%
c = Consumer({
    'bootstrap.servers': '0.0.0.0:9092',
    'group.id': socket.gethostname(),
    'auto.offset.reset': 'latest'
})

# %%
prod_Transaktion_cols={
    0:'Aktion',
    1:'Datum',
    2:'ID_Exemplar',
    3:'ID_Kunde',
    4:'Titel',
    5:'Autor',
    6:'Jahr',
    7:'Art',
    8:'Kennung',
    9:'Zugriffsort'
}

prod_Bewertung_cols={
    0:'Aktion',
    1:'ID_Kunde',
    2:'ID_Buch',
    3:'Wertung',
    4:'Rezension'
}

prod_Neukunden_cols={
    0:'Aktion',
    1:'ID_Kunde',
    2:'Kundennr',
    3:'Vorname_1',
    4:'Vorname_2',
    5:'Nachname',
    6:'Anrede',
    7:'PLZ',
    8:'Strasse',
    9:'Hausnr',
   10:'Mail',
   11:'Tel',
   12:'Geschlecht',
   13:'Geburtsdatum',
   14:'Beruf',
   15:'Titel',
   16:'PersoNr',
   17:'PersoValidTo' 
}

cols=[prod_Transaktion_cols,prod_Bewertung_cols,prod_Neukunden_cols]
topics=["Transaktion", "Bewertung", "Neukunden"]

dfd={}

# %%
for col, topic in zip(cols, topics):
    print(col, topic)

    dfd[topic] = pd.DataFrame(columns=list(col.values()))
    
    
    c.subscribe([topic])
    
    for i in range(60):
        msg = c.poll(1)
        if msg is None:
            continue
    
        mrow = pd.DataFrame([msg.value().decode('utf-8').split(";")]).rename(columns=col)

        dfd[topic]=pd.concat([dfd[topic], mrow])

    dfd[topic] = dfd[topic].reset_index(drop=True)
    #c.close()
# Out:
# {0: 'Aktion', 1: 'Datum', 2: 'ID_Exemplar', 3: 'ID_Kunde', 4: 'Titel', 5: 'Autor', 6: 'Jahr', 7: 'Art', 8: 'Kennung', 9: 'Zugriffsort'} Transaktion
# {0: 'Aktion', 1: 'ID_Kunde', 2: 'ID_Buch', 3: 'Wertung', 4: 'Rezension'} Bewertung
# {0: 'Aktion', 1: 'ID_Kunde', 2: 'Kundennr', 3: 'Vorname_1', 4: 'Vorname_2', 5: 'Nachname', 6: 'Anrede', 7: 'PLZ', 8: 'Strasse', 9: 'Hausnr', 10: 'Mail', 11: 'Tel', 12: 'Geschlecht', 13: 'Geburtsdatum', 14: 'Beruf', 15: 'Titel', 16: 'PersoNr', 17: 'PersoValidTo'} Neukunden

# %%
dfd['Transaktion']
# Out:
#       Aktion                 Datum ID_Exemplar ID_Kunde  \
# 0      Leihe   2024-10-25 17:00:00          68     5568
# 1      Leihe   2024-10-25 20:00:00         153     5252
# 2      Leihe   2024-10-22 01:00:00          87     1119
# 3      Leihe   2024-10-25 23:00:00          63     4060
# 4      Leihe   2024-10-22 04:00:00         173     3242
# 5      Leihe   2024-10-26 02:00:00         148     5052
# 6      Leihe   2024-10-22 04:00:00          90     5211
# 7                                              Fabeln
# 8                                  Tadellöser & Wolff
# 9                                    Gegen den Strich
# 10                            Die Asche meiner Mutter
# 11                          Anrufung des Großen Bären
# 12                                         Kybernetik
# 13                                  Der Begriff Angst
# 14                                   Der große Schlaf
# 15        Architektur. Wege zu einer optischen Kultur
# 16              Handorakel und Kunst der Weltklugheit
# 17                                     Ich, der Robot
# 18                         Gesellschaft im Ueberfluss
# 19                                 So lebt der Mensch
# 20                                       Der Vorleser
# 21                         Unterwegs nach Tschevengur
# 22                                    Haben oder Sein
# 23                       Geschichten vom Herrn Keuner
# 24                                    Fluss ohne Ufer
# 25                Geschichte einer afrikanischen Farm
# 26                                    Schlafes Bruder
# 27                                           Halbzeit
# 28                               Psychologische Typen
# 29                                             Fabian
# 30                               Ungefähre Landschaft
# 31                                   Das Narrenschiff
# 32                                    Die Reiterarmee
# 33                           Geschlecht und Charakter
# 34                                               Kapo
# 35                                     Ich, der Robot
# 36      Die schönsten Sagen des klassischen Altertums
# 37                                            Transit
# 38                                        Don Quijote
# 39                            Der Kummer von Flandern
# 40                                      Die Wolfshaut
# 41                           So zärtlich war Suleyken
# 42                                Guzmán de Alfarache
# 43                                         Austerlitz
# 44                                             Essays
# 45                                    Lady Chatterley
# 46                                 So lebt der Mensch
# 47                               Sexus und Herrschaft
# 48                                       Fahrraddiebe
# 49                                        Eifel-Liebe
# 50                  Der Schüler Gerber hat absolviert
# 51   Geschichte vom braven Kasperl und dem schönen...
# 52                             Die Kartause von Parma
# 53                                         Triptychon
# 54                                    Generation Golf
# 55                                      Simple Storys
# 56                         Herr Gustafsson persönlich
# 57                                 Was am Ende bleibt
# 58                                          Wendezeit
# 59                           Kapitän Nemos Bibliothek
#
#                       Autor     Jahr           Art    Kennung Zugriffsort
# 0             Alan Sillitoe   1959.0     Erzählung   fOT34986    HPk32469
# 1          Jewgeni Samjatin   1924.0         Roman   Ubq83716    Wao53261
# 2             Wilhelm Busch   1865.0    Kinderbuch   YWj72438    sYE07693
# 3                Klaus Mann   1936.0         Roman   dHV28301    eQD65198
# 4             Immanuel Kant   1781.0   Philosophie   MVA79518    RXO82695
# 5         Samuel Richardson   1740.0         Roman   uRp15823    cmi56023
# 6                Carl Sagan   1982.0      Sachbuch   vMH56207    aJe73602
# 7       Jean de La Fontaine   1668.0        Fabeln   FBJ80946    NrX25073
# 8          Walter Kempowski   1971.0         Roman   rqR40938    nlH85346
# 9       Joris-Karl Huysmans   1884.0         Roman   kfM27480    DWI09841
# 10            Frank McCourt   1996.0         Roman   Tbm72581    NXt51348
# 11        Ingeborg Bachmann   1956.0         Lyrik   ouv15372    zku01287
# 12           Norbert Wiener   1948.0      Sachbuch   atU72516    VgH50123
# 13        Søren Kierkegaard   1844.0   Philosophie   zhb41305    ngT15760
# 14         Raymond Chandler   1939.0         Roman   kdS04537    yUv32489
# 15           Walter Gropius   1955.0      Sachbuch   QHG21306    WPV93056
# 16         Baltasar Gracián   1647.0    Aphorismen   cJI87234    CAg93210
# 17             Isaac Asimov   1950.0     Erzählung   BNz12036    Fqa87492
# 18   John Kenneth Galbraith   1958.0      Sachbuch   KxN17409    YBW85209
# 19            André Malraux   1933.0         Roman   Leb49071    mPT80743
# 20         Bernhard Schlink   1995.0         Roman   yTb82690    nOr75249
# 21          Andrej Platonow   1972.0         Roman   lPF42903    qtA40697
# 22              Erich Fromm   1976.0   Philosophie   Ufi42038    lbP63102
# 23           Bertolt Brecht   1949.0     Erzählung   Vsq97021    YBw97140
# 24         Hans Henny Jahnn   1949.0         Roman   hqL70825    kDy35681
# 25          Olive Schreiner   1883.0         Roman   GMj82547    NBt15607
# 26         Robert Schneider   1992.0         Roman   HBR94867    dGy17580
# 27            Martin Walser   1960.0         Roman   SXg38091    yTX95124
# 28                C.G. Jung   1921.0      Sachbuch   upG74159    ZTu06538
# 29            Erich Kästner   1931.0         Roman   TcR08531    DUQ39462
# 30              Peter Stamm   2001.0         Roman   fUp42391    naL62953
# 31    Katherine Anne Porter   1962.0         Roman   Itn06197    jNg56728
# 32              Isaak Babel   1923.0         Roman   rKO38425    zIY72481
# 33           Otto Weininger   1903.0      Sachbuch   WEI58160    GMR16907
# 34         Aleksandar Tišma   1987.0         Roman   OHa01459    iYH65901
# 35             Isaac Asimov   1950.0     Erzählung   BNz12036    Fqa87492
# 36            Gustav Schwab   1838.0     Erzählung   CdR63197    yab27193
# 37             Anna Seghers   1944.0         Roman   yxs21048    RLi70145
# 38      Miguel de Cervantes   1605.0         Roman   wQj08174    ktF27160
# 39               Hugo Claus   1983.0         Roman   DTq76458    uAM63704
# 40              Hans Lebert   1960.0         Roman   nOz42560    LOI50482
# 41           Siegfried Lenz   1955.0         Roman   OIF62374    rmO78629
# 42             Mateo Alemán   1599.0         Roman   boI51407    XhW39601
# 43             W. G. Sebald   2001.0         Roman   UIN10389    oRC51937
# 44      Michel de Montaigne   1580.0     Erzählung   XxA08246    rHB16752
# 45            D.H. Lawrence   1928.0         Roman   HFU76423    Zbo94863
# 46            André Malraux   1933.0         Roman   iay65324    GLj32158
# 47             Kate Millett   1970.0      Sachbuch   lTb78432    HXj74260
# 48          Luigi Bartolini   1946.0         Roman   IbY19784    RpE45283
# 49         Jacques Berndorf   2002.0         Roman   GEb95237    ZfY08453
# 50        Friedrich Torberg   1930.0         Roman   nzU62309    MAd98247
# 51         Clemens Brentano   1817.0       Novelle   ydK01583    bMu85197
# 52                 Stendhal   1839.0         Roman   lrb56879    GUg56201
# 53             Claude Simon   1973.0         Roman   JXd97401    FLh48271
# 54           Florian Illies   2000.0         Roman   Ghg29187    TAE29715
# 55             Ingo Schulze   1998.0         Roman   Lol50297    rpH34607
# 56          Lars Gustafsson   1971.0         Roman   NzB23598    Geb28564
# 57                Paula Fox   1971.0         Roman   KMU75308    LfW53801
# 58            Fritjof Capra   1982.0      Sachbuch   OLx45137    RJB14307
# 59         Per Olov Enquist   1991.0         Roman   WqI65284    vXo73245

# %%
dfd['Bewertung']
# Out:
#        Aktion ID_Kunde ID_Buch Wertung  \
# 0   Bewertung       82     922       8
# 1   Bewertung       27      45       6
# 2   Bewertung       46     181      10
# 3   Bewertung       96     266       8
# 4   Bewertung       47     330       3
# 5   Bewertung      192     258       8
# 6   Bewertung       93     277       5
# 7   Bewertung      248    1036      10
# 8   Bewertung       38     752      10
# 9   Bewertung       17     880       8
# 10  Bewertung       48     424       6
# 11  Bewertung      244     698       8
# 12  Bewertung      209     327       9
# 13  Bewertung        5     547       6
# 14  Bewertung       46     800       2
# 15  Bewertung       16     721       7
# 16  Bewertung      187     354       5
# 17  Bewertung      227     123       5
# 18  Bewertung       27      45       6
# 19  Bewertung       32     614       9
# 20  Bewertung       26     770       7
# 21  Bewertung       97     815       3
# 22  Bewertung       76      25       3
# 23  Bewertung      133     395       4
# 24  Bewertung       95     618       7
# 25  Bewertung       23     152       4
# 26  Bewertung       42     262       4
# 27  Bewertung      201     348       7
# 28  Bewertung      126     680      10
# 29  Bewertung      232     467      10
# 30  Bewertung       32     948       5
# 31  Bewertung      144     906       5
# 32  Bewertung       96     266       8
# 33  Bewertung      105     707       6
# 34  Bewertung       43     876       7
# 35  Bewertung       11     517      10
# 36  Bewertung      227     747       9
# 37  Bewertung      216     431       7
# 38  Bewertung      131     312       7
# 39  Bewertung      166     652       9
# 40  Bewertung      191     380       7
# 41  Bewertung      153      84       3
# 42  Bewertung       44     783       6
# 43  Bewertung      138     446       8
# 44  Bewertung       19     764       1
# 45  Bewertung       96     266       8
# 46  Bewertung      120    1000       5
# 47  Bewertung      126     680      10
# 48  Bewertung      114     192       4
# 49  Bewertung      176     156      10
#
#                                             Rezension
# 0    Ein tiefsinniges Buch, das zum Nachdenken anr...
# 1    Das Buch war in Ordnung, weder herausragend n...
# 2    Ein literarisches Juwel! Das Buch hat mich vo...
# 3                        Packend und gut geschrieben.
# 4    Trotz der interessanten Prämisse fand ich das...
# 5    Ein beeindruckendes Buch, das trotz kleinerer...
# 6                  Durchschnittlich, ohne Highlights.
# 7    Ein literarisches Meisterwerk, das den Leser ...
# 8    Ein absolutes Meisterwerk! Jedes Kapitel war ...
# 9    Sehr gut geschrieben und fesselnd bis zum Sch...
# 10   Ein Buch mit Höhen und Tiefen. Einige Kapitel...
# 11   Dieses Buch hat mich überrascht! Es überzeugt...
# 12   Ein nahezu makelloses Werk, das durch Tiefe u...
# 13   Ein durchschnittliches Buch. Einige Höhepunkt...
# 14   Ein wirklich enttäuschendes Buch. Die Handlun...
# 15   Ein solides Buch mit einigen unerwarteten Wen...
# 16   Ein durchschnittliches Buch, das weder besond...
# 17   Das Buch bietet eine durchschnittliche Erzähl...
# 18   Das Buch war in Ordnung, weder herausragend n...
# 19   Ich war beeindruckt von der Tiefe der Charakt...
# 20   Dieses Buch bietet solide Unterhaltung, wobei...
# 21                     Nicht mein Fall. Enttäuschend.
# 22   Leider hat dieses Buch nicht meine Erwartunge...
# 23                         Nicht wirklich mitreißend.
# 24                        Gut, aber nicht überragend.
# 25   Einige Kapitel waren interessant, aber insges...
# 26   Die Geschichte hätte wirklich Potenzial gehab...
# 27   Ein lohnendes Buch mit gut recherchierten Det...
# 28                              Ein echtes Highlight!
# 29   Ein herausragendes Buch! Von der ersten bis z...
# 30   Das Buch war durchschnittlich. Einige Teile w...
# 31                      Für Zwischendurch in Ordnung.
# 32                       Packend und gut geschrieben.
# 33                           Okay, aber nichts Neues.
# 12   Königsberger Straße    7.0     leonie.meyer@t-online.de     04336/83394
# 13          Sonnenstraße    8.0        amelie.richter@web.de    04323/794097
# 14         Bahnhofstraße    3.0          hanna.lange@gmx.net    03921/596502
# 15             Gartenweg    7.0      nele.herrmann@gmail.com   036083/600872
# 16           Buchenweg 7    nan   marie.schröder@t-online.de    02266/715863
# 17        Kirchstraße 10    nan      niklas.krüger@gmail.com   039408/340390
# 18               Waldweg    4.0        noah.schröder@gmx.net    05921/682524
# 19          Mittelstraße    8.0       sofia.krause@gmail.com   039600/730365
#
#    Geschlecht      Geburtsdatum                    Beruf  Titel    PersoNr  \
# 0           M        1979-01-06           Immobilienwirt   None   JNU07362
# 1           m        1948-03-17                Senior/in   None   OHN41623
# 2           w        1931-10-06               Senior/in    None   OGB35701
# 3           M        1949-10-26                Senior/in   None   WIP69283
# 4           w        1937-02-07                Senior/in   None   SIJ14967
# 5           m        16/12/1957      Fachinformatiker/in   None   CXO08764
# 6           m        01.10.1946                Senior/in   None   SIZ37956
# 7           m        1997-01-15      Fachinformatiker/in   None   RSK43259
# 8           m        06.04.1943               Senior/in     Dr.   XQH35120
# 9           w        11.01.1959   Key Account Manager/in   None   NFB62714
# 10          w        1944-07-30                Senior/in   None   NZO70591
# 11          m        25.07.1977             Data Analyst   None   NUP73052
# 12          w        22/10/1936                Senior/in   None   DKN91743
# 13          w        1997-04-12     Fluglotse/Fluglotsin   None   QGL15428
# 14          W        1993-08-01             Ingenieur/in   None   BJD87145
# 15          w        1931-08-14               Senior/in    None   DDC90843
# 16          w        1929-09-26               Senior/in    None   JGK85240
# 17          m   Mon Dec 30 1946                Senior/in   None   ZYC40273
# 18          m        20.12.1951               Senior/in    None   IKR58407
# 19          w        05/12/1923                Senior/in   None   PIY48260
#
#         PersoValidTo
# 0         2020-10-07
# 1         2024-06-13
# 2         2023-06-20
# 3         26.05.2025
# 4         2023-11-29
# 5         2025-09-14
# 6         2021-07-25
# 7         02/12/2021
# 8    Sun Jun 02 2024
# 9         23.11.2022
# 10        2024-04-24
# 11        2020-12-30
# 12        02.03.2022
# 13        13.02.2021
# 14        2022-02-04
# 15        22.04.2022
# 16        2020-03-01
# 17        03.10.2021
# 18        29.04.2022
# 19        11/07/2024

# %% [markdown]
# # Cleaning der Tabellen

# %% [markdown]
# ### Transaktion

# %%
# IDs zu int konvertieren
dfd['Transaktion']['ID_Exemplar'] = pd.to_numeric(dfd['Transaktion']['ID_Exemplar']).astype(int)
dfd['Transaktion']['ID_Kunde'] = pd.to_numeric(dfd['Transaktion']['ID_Kunde']).astype(int)
# Jahre zu int konvertieren
dfd['Transaktion']['Jahr'] = pd.to_numeric(dfd['Transaktion']['Jahr']).astype(int)

# %% [markdown]
# ### Bewertung

# %%
# IDs zu int konvertieren
dfd['Bewertung']['ID_Kunde'] = pd.to_numeric(dfd['Bewertung']['ID_Kunde']).astype(int)
dfd['Bewertung']['ID_Buch'] = pd.to_numeric(dfd['Bewertung']['ID_Buch']).astype(int)
dfd['Bewertung']['Wertung'] = pd.to_numeric(dfd['Bewertung']['Wertung']).astype(int)

# %% [markdown]
# ### Neukunden

# %%
# IDs zu int konvertieren
dfd['Neukunden']['ID_Kunde'] = pd.to_numeric(dfd['Neukunden']['ID_Kunde']).astype(int)
dfd['Neukunden']['Kundennr'] = pd.to_numeric(dfd['Neukunden']['Kundennr']).astype(int)

# Anreden konsistent machen 
dfd['Neukunden']['Anrede'] = dfd['Neukunden']['Anrede'].replace(['Fr\.'],'Frau', regex=True)
dfd['Neukunden']['Anrede'] = dfd['Neukunden']['Anrede'].replace(['Hr\.'],'Herr', regex=True)
# Titel: "None" to NaN
dfd['Neukunden']['Titel']  = np.where(dfd['Neukunden']['Titel'].str.contains("None"), np.nan, dfd['Neukunden']['Titel'] )
# Vorname_2: "nan" to NaN
dfd['Neukunden']['Vorname_2']  = np.where(dfd['Neukunden']['Vorname_2'].str.contains("nan"), np.nan, dfd['Neukunden']['Vorname_2'] )
# Hausnr: "nan" to NaN
dfd['Neukunden']['Hausnr']  = np.where(dfd['Neukunden']['Hausnr'].str.contains("nan"), np.nan, dfd['Neukunden']['Hausnr'] )
# 4-stellige PLZ mit "0" präfixen 
dfd['Neukunden']['PLZ']    = dfd['Neukunden']['PLZ'].str.strip().str.rjust(5, '0')

# Hausnummern aus Strasse-Spalte extrahieren
def extract_hausnr(strasse):
  if pd.isna(strasse):
    return np.nan
  parts = strasse.split()
  if len(parts) > 1 and parts[-1].isdigit():
    return parts[-1]
  else:
    return np.nan
#Apply extract_hausnr, wenn 'Hausnr' NaN und entferne die Hausnummern aus der Strasse Spalte
dfd['Neukunden'].loc[dfd['Neukunden']['Hausnr'].isnull(), 'Hausnr'] = dfd['Neukunden'].loc[dfd['Neukunden']['Hausnr'].isnull(), 'Strasse'].apply(extract_hausnr)
dfd['Neukunden']['Strasse'] = dfd['Neukunden']['Strasse'].str.rsplit(expand=True)[0]
# Convert Hausnr to int
dfd['Neukunden']['Hausnr'] = pd.to_numeric(dfd['Neukunden']['Hausnr']).astype(int)

# Geschlecht konsistent machen 
dfd['Neukunden']['Geschlecht'] = dfd['Neukunden']['Geschlecht'].str.strip().replace(["^w$", "^W$"],'Weiblich', regex=True)
dfd['Neukunden']['Geschlecht'] = dfd['Neukunden']['Geschlecht'].str.strip().replace(["^m$", "^M$"],'Männlich', regex=True)

# Datumsspalten konsistent machen
dfd['Neukunden']['Geburtsdatum'] = pd.to_datetime(dfd['Neukunden']['Geburtsdatum'],format='mixed', dayfirst=True)
dfd['Neukunden']['PersoValidTo'] = pd.to_datetime(dfd['Neukunden']['PersoValidTo'],format='mixed', dayfirst=True)

# %% [markdown]
# ### Bestand

# %%
# Jahre zu int konvertieren
df_bestand['Jahr'] = pd.to_numeric(df_bestand['Jahr']).astype('Int64', errors='ignore')

# %% [markdown]
# # Aufbau der Tabellen für das Core DWH

# %%
dfs={}

# %%
Kunde_cols={
    0:'ID_Kunde',
    1:'ID_Mitgliedsstatus',
    2:'Kundennr',
    3:'Vorname_1',
    4:'Vorname_2',
    5:'Nachname',
    6:'Anrede',
    7:'Titel',
    8:'PLZ',
    9:'Strasse',
   10:'Hausnr',
   11:'Mail',
   12:'Tel',
   13:'Geschlecht',
   14:'Geburtsdatum',
   15:'Beruf',
   16:'PersoNr',
   17:'PersoValidTo', 
   18:'Mitglied seit',
   19:'Mitglied bis' 
}

Bewertung_cols={
    1:'ID_Kunde',
    2:'ID_Buch',
    3:'Wertung',
    4:'Rezension'
}

Buch_cols={
    1:'ID_Kunde',
    2:'ID_Buch',
    3:'Wertung',
    4:'Rezension'
}

Exemplare_cols={
    1:'ID_Bestand',
    2:'Nr',
    3:'Kennung',
    4:'Zugriffsort',
    5:'Zustand'
}

Buch_cols={
    1:'ID_Autor',
    2:'Nr',
    3:'Titel',
    4:'Jahr',
    5:'Art',
}

Leihe_cols={
    0:'ID_Kunde',
    1:'ID_Exemplar',
    2:'Ausleihdatum',
    3:'Rueckgabedatum',
    4:'Verlaengerungsstatus',
    5:'Mahnstatus',
    6:'Fernleihe'
}

Mitgliedsstatus_cols={
    0:'ID_Mitgliedsstatus',
    2:'Bezeichnung',
    3:'Jahresbeitrag',
    4:'Mahnbetrag'
}

Beitragszahlung_cols={
    0:'ID_Zahlung',
    2:'ID_Kunde',
    3:'Datum',
    4:'Betrag',
}

# %%
dfs['Kunde']     = dfd['Neukunden'].reindex(columns=list(Kunde_cols.values()))
dfs['Bewertung'] = dfd['Bewertung'].reindex(columns=list(Bewertung_cols.values()))
dfs['Exemplare'] = df_bestand.reindex(columns=list(Exemplare_cols.values())).rename(columns={
                                                                        'ID_Bestand':'ID_Exemplar',
                                                                        'Nr':'ID_Buch'    
                                                                        })

dfs['Autor']   = df_bestand[['Autor', 'Herkunft']].drop_duplicates().reset_index(drop=True).reset_index().rename(columns={'index':'ID_Autor'})

dfs['Buch']    = pd.merge(df_bestand, 
                          dfs['Autor'], 
                          on=['Autor']
                         )[list(Buch_cols.values())]                                  \
                                                    .drop_duplicates()                \
                                                    .reset_index(drop=True)           \
                                                    .rename(columns={'Nr':'ID_Buch'})

dfs['Leihe'] = dfd['Transaktion'].reindex(columns=list(Leihe_cols.values())).reset_index().rename(columns={'index':'ID_Leihe'})


### more ###
dfs['Mitgliedsstatus'] = pd.DataFrame(columns=list(Mitgliedsstatus_cols.values()))
dfs['Beitragszahlung'] = dfd['Neukunden'].reindex(columns=list(Beitragszahlung_cols.values()))

# %% [markdown]
# # Schicke die Tabellen an den SQL Server

# %%
from sqlalchemy import create_engine, inspect, text

USER = 'root'
PASSWORD = 'root'
HOST = 'localhost'          # see yml file
PORT = 3307
DATABASE = 'test_db_1'
 

def get_connection(database=DATABASE):
    return create_engine(
        url="mysql+pymysql://{0}:{1}@{2}:{3}/{4}"\
            .format(USER, PASSWORD, HOST, PORT, database)
    )

engine = get_connection('mysql')
with engine.connect() as connection:
    insp = inspect(engine)
    db_list = insp.get_schema_names()
    print(f"Connection to the {HOST} for user {USER} created successfully.")
    if DATABASE not in db_list:
        sql = text(f"CREATE DATABASE {DATABASE} CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;")
        result = connection.execute(sql)
        if result:
            print(f"Database {DATABASE} created!")
# Out:
# Connection to the localhost for user root created successfully.

# %%
for Tabelle in dfs.keys():
    dfs[Tabelle].to_sql(Tabelle, con=engine,schema=DATABASE, index=False, if_exists='append')
